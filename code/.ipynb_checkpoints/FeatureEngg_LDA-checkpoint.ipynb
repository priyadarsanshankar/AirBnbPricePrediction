# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing
import matplotlib.pyplot as plt
#from haversine import haversine 
from progressbar import ProgressBar
import yaml

## for text field processing
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn import datasets, feature_extraction, decomposition
from nltk.stem.porter import PorterStemmer

import gensim
from gensim import corpora
import re
import stop_words
from stop_words import get_stop_words
import operator

## for topic visualization
import pyLDAvis
import pyLDAvis.gensim

# %%
listings = pd.read_csv('data/airbnb_listings.csv')

# %%
#Import the for loop progress bar
pbar = ProgressBar()

# %%
## Finding sentiment intensity score for description field
## saving "compound" score to listings dataframe

listings["Description_Length"] = np.nan
sent_int = SentimentIntensityAnalyzer()

for i in range(len(listings["description"])):
    s = listings['description'][i]
    
    ## generating sentiment intensity score for descriptions
    sentiment = sent_int.polarity_scores(s)
    listings.loc[i, "Sentiment_intensity"] = sentiment["compound"]
    
    ## Findig the length of the description
    listings.loc[i,"Description_Length"] = len(listings["description"][i].split())

# %%
## Topic modelling on description using LDA
stop = get_stop_words('en')
add_stop_word = ['etc', 'well', 'll', 'get', 'within, ''please', 'good', 'many', 'l', 'g', 'c', 
                 'want']
stop.extend(add_stop_word)
desc = []

## Creating a list of description
desc_list = [listings["description"][i] for i in range(len(listings["description"]))]

for i in desc_list:
    ## tokanizing descrption into words
    desc_list_w = nltk.tokenize.word_tokenize(i)
    
    ## converting all words to lower case
    desc_lower = [w.lower() for w in desc_list_w]
    
    ## removing numerical values and special characters
    desc_words = [w for w in desc_lower if re.search('^[a-z]+$',w)]
    
    ## removing stop words
    desc_stopremoved = [w for w in desc_words if w not in stop]
    
    ## add tokens to list
    desc.append(desc_stopremoved)

# %%
## Gensim's Dictionary encapsulates the mapping between words and their integer ids. 
desc_dict = corpora.Dictionary(desc)

## filter out words which appear in less than 20 documents or more than 15% documents
desc_dict.filter_extremes(no_below=20, no_above=0.15) 
print(desc_dict)

## creating bag of words
corpus = [desc_dict.doc2bow(d) for d in desc]
len(corpus)
# Out:
# Dictionary(7556 unique tokens: ['sunlit', 'brownstone', 'loveliest', 'brooklyn', 'promenade']...)
# 74111

# %%
## training an LDA model
lda_model = gensim.models.LdaModel(corpus, alpha='auto', num_topics=5, id2word=desc_dict)

# %%
## printing topics for lda model
lda_model.show_topics(num_topics=5,num_words=30)
# Out:
# [(0,
#   '0.011*"brooklyn" + 0.007*"east" + 0.007*"nyc" + 0.006*"around" + 0.006*"square" + 0.006*"trains" + 0.005*"best" + 0.005*"minute" + 0.005*"shops" + 0.005*"right" + 0.005*"williamsburg" + 0.005*"cozy" + 0.005*"york" + 0.005*"min" + 0.005*"lots" + 0.005*"apt" + 0.005*"francisco" + 0.005*"village" + 0.005*"light" + 0.005*"san" + 0.005*"like" + 0.005*"easy" + 0.004*"time" + 0.004*"side" + 0.004*"central" + 0.004*"shared" + 0.004*"amazing" + 0.004*"safe" + 0.004*"everything" + 0.004*"perfect"'),
#  (1,
#   '0.008*"fully" + 0.007*"closet" + 0.007*"dining" + 0.007*"bedrooms" + 0.007*"use" + 0.006*"towels" + 0.006*"microwave" + 0.006*"table" + 0.006*"floors" + 0.006*"mattress" + 0.006*"cable" + 0.006*"air" + 0.006*"small" + 0.006*"bath" + 0.005*"guest" + 0.005*"sofa" + 0.005*"shower" + 0.005*"equipped" + 0.005*"unit" + 0.005*"dryer" + 0.005*"furnished" + 0.005*"shared" + 0.005*"renovated" + 0.005*"beds" + 0.005*"modern" + 0.004*"high" + 0.004*"couch" + 0.004*"desk" + 0.004*"appliances" + 0.004*"flat"'),
#  (2,
#   '0.012*"metro" + 0.011*"line" + 0.011*"station" + 0.010*"center" + 0.010*"boston" + 0.010*"bus" + 0.009*"dc" + 0.007*"square" + 0.006*"central" + 0.006*"chicago" + 0.006*"minute" + 0.006*"within" + 0.005*"historic" + 0.005*"public" + 0.005*"red" + 0.005*"shopping" + 0.005*"easy" + 0.005*"hill" + 0.005*"capitol" + 0.005*"stop" + 0.005*"condo" + 0.004*"university" + 0.004*"min" + 0.004*"circle" + 0.004*"steps" + 0.004*"near" + 0.004*"transportation" + 0.004*"district" + 0.004*"short" + 0.004*"north"'),
#  (3,
#   '0.014*"hollywood" + 0.009*"pool" + 0.008*"views" + 0.005*"los" + 0.005*"guest" + 0.005*"modern" + 0.005*"hills" + 0.005*"patio" + 0.005*"view" + 0.005*"la" + 0.004*"outdoor" + 0.004*"angeles" + 0.004*"like" + 0.004*"unit" + 0.004*"amenities" + 0.004*"best" + 0.004*"property" + 0.004*"garden" + 0.004*"sunset" + 0.004*"deck" + 0.003*"gym" + 0.003*"studio" + 0.003*"open" + 0.003*"bath" + 0.003*"perfect" + 0.003*"west" + 0.003*"style" + 0.003*"front" + 0.003*"check" + 0.003*"luxury"'),
#  (4,
#   '0.024*"beach" + 0.016*"travelers" + 0.016*"business" + 0.015*"solo" + 0.015*"couples" + 0.014*"adventurers" + 0.010*"la" + 0.010*"hollywood" + 0.009*"santa" + 0.009*"venice" + 0.008*"monica" + 0.007*"miles" + 0.006*"min" + 0.006*"bus" + 0.006*"shopping" + 0.006*"drive" + 0.006*"families" + 0.006*"shops" + 0.005*"los" + 0.005*"safe" + 0.005*"easy" + 0.005*"center" + 0.005*"kids" + 0.005*"angeles" + 0.004*"beverly" + 0.004*"public" + 0.004*"blvd" + 0.004*"metro" + 0.004*"hills" + 0.004*"everything"')]

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, desc_dict)
pyLDAvis.show(vis)

#http://127.0.0.1:8889/#topic=0&lambda=1&term=
# Out:
# Note: if you're in the IPython notebook, pyLDAvis.show() is not the best command
#       to use. Consider using pyLDAvis.display(), or pyLDAvis.enable_notebook().
#       See more information at http://pyLDAvis.github.io/quickstart.html .
#
# You must interrupt the kernel to end this command
#
# Serving to http://127.0.0.1:8889/    [Ctrl-C to exit]
# 127.0.0.1 - - [31/Oct/2018 13:54:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Oct/2018 13:54:18] "GET /LDAvis.css HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Oct/2018 13:54:18] "GET /d3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Oct/2018 13:54:18] "GET /LDAvis.js HTTP/1.1" 200 -
# stopping Server...

# %%
## generating topic describution over each description

listings["topic_general"] = 0.0        ## for topic 0
listings["Topic_utilities"] = 0.0      ## for topic 1
listings["Topic_Transport"] = 0.0      ## for topic 2
listings["Topic_listing_desc"] = 0.0   ## for topic 3
listings["Topic_attractions"] = 0.0    ## for topic 4

## defining topic_name to assign topic names
def topic_name(i):
        switcher={
                0:'topic_general',
                1:'Topic_utilities',
                2:'Topic_Transport',
                3:'Topic_listing_desc',
                4:'Topic_attractions',
             }
        return switcher.get(i,"Invalid")
        
for d in range(len(listings["description"])):
    bow = desc_dict.doc2bow(desc[d])
    t = lda_model.get_document_topics(bow)
    
    for i in range(len(t)):
        #print("description", d, ":", t[i][0], t[i][1])
        temp = topic_name(t[i][0])
        listings.loc[d,temp] = t[i][1]
    #print("------")

# %%
listings.head(-10)
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# 5      12422935   4.442651     Apartment     Private room
# 6      11825529   4.418841     Apartment  Entire home/apt
# 7      13971273   4.787492   Condominium  Entire home/apt
# 8        180792   4.787492         House     Private room
# 9       5385260   3.583519         House     Private room
# 10      5578513   4.605170     Apartment     Private room
# 11     17423675   5.010635         House  Entire home/apt
# 12     14066228   4.248495     Apartment     Private room
# 13      2658946   5.298317     Apartment  Entire home/apt
# 14       583490   4.955827     Apartment  Entire home/apt
# 15      6226658   4.094345     Apartment     Private room
# 16      7499179   4.317488          Loft     Private room
# 17     14648556   4.595120     Townhouse     Private room
# 18     17589436   4.882802     Apartment  Entire home/apt
# 19     18224863   4.595120         House  Entire home/apt
# 20      7264511   4.382027         House     Private room
# 21     16679342   3.688879         House     Private room
# 22      3563677   4.905275     Apartment  Entire home/apt
# 23     17615783   4.007333         House     Private room
# 24      2479317   6.956545     Apartment  Entire home/apt
# 25     14122244   5.003946     Apartment  Entire home/apt
# 26     19407360   4.553877     Apartment  Entire home/apt
# 27     14490881   5.003946     Apartment  Entire home/apt
# 28       851978   5.192957     Apartment  Entire home/apt
# 29      4734170   4.653960     Apartment     Private room
# ...         ...        ...           ...              ...
# 74071     64574   5.241747     Apartment  Entire home/apt
# 74072    286311   4.382027         House     Private room
# 74073  18822021   4.553877     Townhouse     Private room
# 74074   5650732   4.382027     Apartment     Private room
# 74075  21151013   4.605170     Apartment     Private room
# 74076   1373456   5.010635     Apartment  Entire home/apt
# 74077   9826494   4.174387         House     Private room
# 74078  11554877   4.859812     Apartment  Entire home/apt
# 74079  15898650   5.978886     Apartment  Entire home/apt
# 74080  14851530   4.605170          Loft  Entire home/apt
# 74081  13996915   6.907755         Other  Entire home/apt
# 74082  15913471   4.174387         House     Private room
# 74083  15423281   5.010635     Apartment     Private room
# 74084  10387373   5.843544         Other  Entire home/apt
# 74085  16208920   4.653960     Apartment  Entire home/apt
# 74086    224510   4.174387         House     Private room
# 74087  15042259   4.477337     Apartment  Entire home/apt
# 74088  18997559   4.905275         House  Entire home/apt
# 74089   4550722   4.605170         House     Private room
# 74090   9704912   4.317488         House     Private room
# 74091   3779249   5.010635     Apartment  Entire home/apt
# 74092  18395940   4.700480     Apartment  Entire home/apt
# 74093  14838304   4.948760         House  Entire home/apt
# 74094     38663   3.688879     Apartment     Private room
# 74095   2278677   4.382027     Apartment  Entire home/apt
# 74096   7331958   3.912023     Apartment     Private room
# 74097  15952947   4.700480     Apartment     Private room
# 74098   8342838   4.553877     Apartment  Entire home/apt
# 74099   4615631   4.276666   Condominium     Private room
# 74100  13862304   4.605170     Apartment     Private room
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# 2      {TV,"Cable TV","Wireless Internet","Air condit...             5
# 3      {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 4      {TV,Internet,"Wireless Internet","Air conditio...             2
# 5      {TV,"Wireless Internet",Heating,"Smoke detecto...             2
# 6      {TV,Internet,"Wireless Internet","Air conditio...             3
# 7      {TV,"Cable TV","Wireless Internet","Wheelchair...             2
# 8      {TV,"Cable TV","Wireless Internet","Pets live ...             2
# 9      {"Wireless Internet","Air conditioning",Kitche...             2
# 10     {Internet,"Wireless Internet","Air conditionin...             2
# 11     {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 12     {TV,Internet,"Wireless Internet",Kitchen,"Free...             2
# 13     {TV,"Cable TV",Internet,"Wireless Internet","A...             6
# 14     {Kitchen,Heating,"Smoke detector","Carbon mono...             2
# 15     {Internet,"Wireless Internet","Air conditionin...             2
# 16     {TV,"Wireless Internet",Kitchen,"Pets allowed"...             2
# 17     {Internet,"Wireless Internet","Air conditionin...             2
# 18     {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 19     {TV,"Wireless Internet","Air conditioning",Kit...             8
# 20     {"Cable TV",Internet,"Wireless Internet","Air ...             2
# 21     {Internet,"Air conditioning",Kitchen,"Smoking ...             2
# 22     {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 23     {Internet,"Wireless Internet","Air conditionin...             2
# 24     {TV,"Wireless Internet","Air conditioning",Kit...             4
# 25     {TV,"Cable TV",Internet,"Wireless Internet","A...             6
# 26     {TV,"Wireless Internet",Pool,Kitchen,"Elevator...             2
# 27     {TV,"Cable TV","Wireless Internet","Air condit...             4
# 28     {TV,Internet,"Wireless Internet","Air conditio...             3
# 29     {TV,Internet,"Wireless Internet","Air conditio...             3
# ...                                                  ...           ...
# 74071  {TV,Internet,"Wireless Internet","Air conditio...             4
# 74072  {TV,Internet,"Wireless Internet",Heating,Washe...             2
# 74073  {TV,"Cable TV",Internet,"Wireless Internet","A...             3
# 74074  {"Wireless Internet","Air conditioning",Kitche...             2
# 74075  {TV,"Wireless Internet","Air conditioning",Kit...             2
# 74076  {"Wireless Internet",Kitchen,"Pets allowed",El...             5
# 74077  {Internet,"Wireless Internet","Air conditionin...             2
# 74078  {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 74079  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 74080  {TV,Internet,"Wireless Internet","Air conditio...             2
# 74081  {TV,"Wireless Internet","Air conditioning",Kit...            16
# 74082  {TV,"Cable TV",Internet,"Wireless Internet","F...             1
# 74083  {TV,"Wireless Internet",Kitchen,"Smoke detecto...             2
# 74084  {TV,"Wireless Internet","Air conditioning",Kit...             4
# 74085  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 74086  {TV,"Wireless Internet",Heating,"Smoke detecto...             2
# 74087  {TV,"Wireless Internet","Air conditioning",Poo...             4
# 74088  {TV,Internet,"Wireless Internet","Air conditio...             5
# 74089  {TV,"Cable TV",Internet,"Air conditioning",Poo...             2
# 74090  {TV,Internet,"Smoke detector","Wireless Intern...             2
# 74091  {"Wireless Internet","Air conditioning",Kitche...             2
# 74092  {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 74093  {TV,"Cable TV",Internet,"Wireless Internet","A...             4
# 74094  {TV,Internet,"Wireless Internet","Air conditio...             2
# 74095  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 74096  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 74097  {Internet,"Wireless Internet","Air conditionin...             2
# 74098  {Internet,"Wireless Internet","Air conditionin...             4
# 74099  {TV,Internet,"Wireless Internet","Air conditio...             2
# 74100  {Internet,"Wireless Internet","Air conditionin...             2
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee  \
# 0            1.0  Real Bed              strict          True
# 1            1.0  Real Bed              strict          True
# 2            1.0  Real Bed            moderate          True
# 3            1.0  Real Bed            flexible          True
# 4            1.0  Real Bed            moderate          True
# 5            1.0  Real Bed              strict          True
# 6            1.0  Real Bed            moderate          True
# 7            1.0  Real Bed            moderate          True
# 8            1.0  Real Bed            moderate          True
# 9            1.0  Real Bed            moderate          True
# 10           1.0  Real Bed              strict          True
# 11           1.5  Real Bed              strict          True
# 12           1.0  Real Bed            flexible          True
# 13           1.5  Real Bed              strict          True
# 14           1.0  Real Bed              strict          True
# 15           1.5  Real Bed            moderate          True
# 16           1.0  Real Bed              strict         False
# 17           2.0  Real Bed              strict          True
# 18           1.0  Real Bed              strict          True
# 19           1.0  Real Bed              strict          True
# 20           1.0  Real Bed              strict          True
# 21           1.5  Real Bed              strict          True
# 22           1.0  Real Bed            moderate          True
# 23           1.0  Real Bed            moderate          True
# 24           1.0  Real Bed            moderate          True
# 25           1.0  Real Bed              strict          True
# 26           1.0  Real Bed            flexible          True
# 27           1.0  Real Bed              strict          True
# 28           1.0  Real Bed            flexible          True
# 29           1.0  Real Bed              strict          True
# ...          ...       ...                 ...           ...
# 74071        1.0  Real Bed            flexible         False
# 74072        1.0  Real Bed            flexible          True
# 74073        1.0  Real Bed              strict          True
# 74074        1.0  Real Bed            flexible         False
# 74075        1.0  Real Bed            flexible         False
# 74076        1.0  Real Bed              strict          True
# 74077        1.0  Real Bed              strict          True
# 74078        2.0  Real Bed              strict          True
# 74079        1.0  Real Bed            moderate          True
# 74080        1.0  Real Bed            flexible         False
# 74081        1.0  Real Bed            moderate         False
# 74082        1.0  Real Bed            flexible          True
# 74083        1.0  Real Bed            flexible         False
# 74084        1.0  Real Bed              strict         False
# 74085        1.0  Real Bed            flexible         False
# 74086        1.0  Real Bed              strict          True
# 74087        1.0  Real Bed              strict          True
# 74088        2.5  Real Bed            flexible         False
# 74089        1.0  Real Bed              strict          True
# 74090        1.0  Real Bed            flexible         False
# 74091        1.0  Real Bed            moderate         False
# 74092        2.0  Real Bed              strict          True
# 74093        1.0  Real Bed              strict          True
# 74094        1.0  Real Bed              strict          True
# 74095        1.0  Real Bed            flexible         False
# 74096        1.0  Real Bed            flexible         False
# 74097        1.0  Real Bed            flexible          True
# 74098        1.0  Real Bed            flexible          True
# 74099        1.0  Real Bed            moderate          True
# 74100        1.0  Real Bed              strict          True
#
#              ...          zipcode bedrooms beds Description_Length  \
# 0            ...            11201      1.0  1.0               31.0
# 1            ...            10019      3.0  3.0              168.0
# 2            ...            10027      1.0  3.0              167.0
# 3            ...          94117.0      2.0  2.0               78.0
# 4            ...            20009      0.0  1.0              115.0
# 5            ...            94131      1.0  1.0              164.0
# 6            ...            90292      1.0  1.0              158.0
# 7            ...            90015      1.0  1.0              164.0
# 8            ...            94121      1.0  1.0              172.0
# 9            ...            91748      1.0  1.0              121.0
# 10           ...          10009.0      1.0  1.0              168.0
# 11           ...            90254      2.0  2.0              178.0
# 12           ...            90277      1.0  1.0               55.0
# 13           ...            20009      2.0  3.0              173.0
# 14           ...            90804      1.0  1.0              171.0
# 15           ...            60622      1.0  1.0              180.0
# 16           ...            60622      1.0  1.0              115.0
# 17           ...            02127      1.0  1.0              152.0
# 18           ...            10002      1.0  2.0              178.0
# 19           ...          11226.0      3.0  3.0              127.0
# 20           ...            91401      1.0  1.0              190.0
# 21           ...          11212.0      1.0  1.0              158.0
# 22           ...            90015      1.0  1.0              152.0
# 23           ...            91401      1.0  1.0              176.0
# 24           ...            20009      1.0  2.0              174.0
# 25           ...          11411.0      3.0  3.0              174.0
# 26           ...              NaN      1.0  1.0               69.0
# 27           ...            11374      2.0  2.0               32.0
# 28           ...            90028      1.0  2.0               50.0
# 29           ...            10016      1.0  2.0               39.0
# ...          ...              ...      ...  ...                ...
# 74071        ...            11102      1.0  1.0               75.0
# 74072        ...            94112      1.0  1.0              168.0
# 74073        ...            20036      2.0  2.0              175.0
# 74074        ...          10002.0      1.0  1.0               43.0
# 74075        ...          10009.0      1.0  1.0              141.0
# 74076        ...            02215      2.0  2.0              193.0
# 74077        ...            91104      1.0  1.0              178.0
# 74078        ...            02215      1.0  2.0              161.0
# 74079        ...            94133      2.0  2.0              155.0
# 74080        ...          11237.0      0.0  1.0               43.0
# 74081        ...            91606      1.0  1.0              179.0
# 74082        ...            94110      1.0  1.0              174.0
# 74083        ...              NaN      1.0  1.0               19.0
# 74084        ...          11211.0      2.0  3.0              117.0
# 74085        ...            20009      1.0  1.0              168.0
# 74086        ...            11413      0.0  1.0              113.0
# 74087        ...            90017      0.0  2.0               79.0
# 74088        ...            20002      2.0  2.0               75.0
# 74089        ...            91001      1.0  1.0              176.0
# 74090        ...            11434      1.0  1.0              164.0
# 74091        ...          10009.0      0.0  1.0              150.0
# 74092        ...            60610      2.0  3.0              115.0
# 74093        ...            20009      1.0  1.0              184.0
# 74094        ...          10035.0      1.0  1.0              188.0
# 74095        ...            11209      1.0  1.0               30.0
# 74096        ...            10032      1.0  1.0              168.0
# 74097        ...          10011.0      1.0  1.0              163.0
# 74098        ...            90028      0.0  2.0              150.0
# 74099        ...            90046      1.0  1.0              152.0
# 74100        ...          11211.0      1.0  1.0              177.0
#
#       Sentiment_intensity topic_general Topic_utilities Topic_Transport  \
# 0                  0.8658      0.940199        0.021884        0.012032
# 1                  0.9755      0.335603        0.185079        0.448822
# 2                  0.9420      0.000000        0.822422        0.169054
# 3                  0.8513      0.968196        0.011978        0.000000
# 4                  0.9401      0.361290        0.000000        0.628243
# 5                  0.9564      0.482964        0.456538        0.000000
# 6                  0.9915      0.069379        0.000000        0.000000
# 7                  0.9089      0.000000        0.000000        0.383790
# 8                  0.9913      0.048999        0.569324        0.027008
# 9                  0.6369      0.000000        0.000000        0.000000
# 10                 0.9595      0.875224        0.078222        0.000000
# 11                 0.9582      0.116527        0.392644        0.000000
# 12                 0.8974      0.011902        0.010957        0.000000
# 13                 0.9785      0.280148        0.318506        0.354787
# 14                 0.9884      0.000000        0.155053        0.000000
# 15                 0.9932      0.412351        0.000000        0.084554
# 16                 0.9347      0.161634        0.000000        0.457025
# 17                 0.9759      0.000000        0.019443        0.688790
# 18                 0.9935      0.836450        0.000000        0.000000
# 19                 0.8910      0.605665        0.000000        0.383844
# 20                 0.9878      0.099003        0.382359        0.000000
# 21                 0.9628      0.771039        0.000000        0.000000
# 22                 0.9382      0.035434        0.000000        0.217817
# 23                 0.9883      0.060556        0.389705        0.000000
# 24                -0.4482      0.000000        0.620101        0.369842
# 25                 0.9943      0.000000        0.569855        0.000000
# 26                 0.9655      0.000000        0.099513        0.000000
# 27                 0.8555      0.018690        0.017368        0.508255
# 28                 0.9569      0.012602        0.391975        0.000000
# 29                 0.9151      0.427244        0.017432        0.534708
# ...                   ...           ...             ...             ...
# 74071              0.9816      0.525933        0.455179        0.000000
# 74072              0.9780      0.408348        0.385911        0.000000
# 74073              0.9792      0.000000        0.241246        0.749932
# 74074              0.2023      0.917917        0.031721        0.016080
# 74075              0.5255      0.895234        0.000000        0.000000
# 74076              0.9917      0.752451        0.037854        0.203755
# 74077              0.9763      0.000000        0.795077        0.000000
# 74078              0.9260      0.000000        0.000000        0.987674
# 74079              0.9739      0.732818        0.000000        0.144377
# 74080              0.8225      0.491502        0.478299        0.000000
# 74081              0.5093      0.000000        0.636297        0.022039
# 74082              0.9786      0.255266        0.605151        0.029860
# 74083              0.7184      0.065086        0.023713        0.013182
# 74084              0.9172      0.984876        0.000000        0.000000
# 74085              0.6285      0.000000        0.469123        0.521632
# 74086              0.9531      0.365562        0.072874        0.283602
# 74087              0.9327      0.000000        0.000000        0.000000
# 74088              0.7579      0.010470        0.277249        0.700850
# 74089              0.9554      0.000000        0.130353        0.000000
# 74090              0.8122      0.000000        0.901505        0.000000
# 74091              0.5719      0.783184        0.180486        0.030699
# 74092             -0.2003      0.000000        0.000000        0.696515
# 74093              0.9941      0.182788        0.684502        0.127192
# 74094              0.9754      0.667982        0.204467        0.069394
# 74095              0.7964      0.907284        0.035925        0.018071
# 74096              0.9334      0.754549        0.000000        0.124137
# 74097              0.9647      0.205811        0.752858        0.000000
# 74098              0.9380      0.064030        0.051261        0.067254
# 74099              0.9947      0.000000        0.226512        0.000000
# 74100              0.9825      0.284883        0.419506        0.027680
#
#       Topic_listing_desc  Topic_attractions
# 0               0.013794           0.012090
# 1               0.028165           0.000000
# 2               0.000000           0.000000
# 3               0.000000           0.000000
# 4               0.000000           0.000000
# 5               0.000000           0.055427
# 6               0.064509           0.861585
# 7               0.345340           0.263159
# 8               0.352264           0.000000
# 9               0.975819           0.000000
# 10              0.040898           0.000000
# 11              0.000000           0.485670
# 12              0.708196           0.263170
# 13              0.000000           0.044415
# 14              0.765592           0.071654
# 15              0.496632           0.000000
# 16              0.000000           0.370697
# 17              0.000000           0.286239
# 18              0.156257           0.000000
# 19              0.000000           0.000000
# 20              0.254676           0.261432
# 21              0.000000           0.218870
# 22              0.249641           0.493716
# 23              0.000000           0.545254
# 24              0.000000           0.000000
# 25              0.000000           0.420876
# 26              0.516217           0.371309
# 27              0.446644           0.000000
# 28              0.583361           0.000000
# 29              0.010982           0.000000
# ...                  ...                ...
# 74071           0.000000           0.000000
# 74072           0.144430           0.059530
# 74073           0.000000           0.000000
# 74074           0.018251           0.016031
# 74075           0.093688           0.000000
# 74076           0.000000           0.000000
# 74077           0.059338           0.140319
# 74078           0.000000           0.000000
# 74079           0.116633           0.000000
# 74080           0.010972           0.000000
# 74081           0.335471           0.000000
# 74082           0.107600           0.000000
# 74083           0.014915           0.883104
# 74084           0.000000           0.000000
# 74085           0.000000           0.000000
# 74086           0.000000           0.274682
# 74087           0.497457           0.481328
# 74088           0.000000           0.000000
# 74089           0.596134           0.267402
# 74090           0.000000           0.090063
# 74091           0.000000           0.000000
# 74092           0.057268           0.232197
# 74093           0.000000           0.000000
# 74094           0.056035           0.000000
# 74095           0.020581           0.018138
# 74096           0.000000           0.111946
# 74097           0.036889           0.000000
# 74098           0.305355           0.512100
# 74099           0.675137           0.092371
# 74100           0.265642           0.000000
#
# [74101 rows x 36 columns]

# %%
## write df to csv file
#listings.columns
listings.to_csv("data/airbnb_listings_LDA.csv", encoding='utf-8', index=False)
